# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import style
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import seaborn as sns

# %%
df_gold = pd.read_csv("D:\Intro Data Analytics\Exercise2\gold_price.csv")
df_silver = pd.read_csv("D:\Intro Data Analytics\Exercise2\silver_price.csv")

df_gold.isna().sum()
#df_gold.plot(kind="hist")
# Out:
# date       0
# price    141
# dtype: int64

# %%
df_gold['price'].fillna((df_gold['price'].mean()), inplace=True)

df_silver['price'].fillna((df_silver['price'].mean()), inplace=True)
# Out:
# C:\Users\vmgem\AppData\Local\Temp\ipykernel_8276\840747700.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_silver['price'].fillna((df_silver['price'].mean()), inplace=True)

# %%
df_gold.head()
# Out:
#          date      price
# 0  1968-01-02  565.37297
# 1  1968-01-03  565.37297
# 2  1968-01-04  565.37297
# 3  1968-01-05  565.37297
# 4  1968-01-08  565.37297

# %%
df_silver['date'] = pd.to_datetime(df_silver['date'])
date = df_silver['date']
silver_price = df_silver['price']
gold_price = df_gold['price']

fig, ax = plt.subplots(figsize=(8, 6))
#fig, ax1 = plt.subplots(figsize=(8, 6))
ax.plot(date, silver_price);

# %%
df_gold['date'] = pd.to_datetime(df_gold['date'])
date1 = df_gold['date']
gold_price = df_gold['price']

fig, ax1 = plt.subplots(figsize=(8, 6))
ax1.plot(date1, gold_price);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vmgem\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ...

# %%
#df_gold.rename(columns={"price": "Gold Price"})
df_silver.rename(columns={"price": "Silver Price", 'data': 'Date'})
df_silver.head()
# Out:
#         date  price
# 0 1968-01-02  2.173
# 1 1968-01-03  2.225
# 2 1968-01-04  2.171
# 3 1968-01-05  2.157
# 4 1968-01-08  2.163

# %%
df_gold_silver = pd.concat([df_gold, df_silver], axis=1, join='inner')
display(df_gold_silver)

#df = df[['favorite_color','grade','name','age']]
# Out:
# Empty DataFrame
# Columns: [price, date, price]
# Index: []
